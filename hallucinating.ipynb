# %%
import re
import spacy
from spacy import load

# %%
nlp = load('en_core_web_sm')
legal_document = """
Case Name: Church of Hope v. Internal Revenue Service (D.C. Md. 2023)
● The Church of Hope (Plaintiff), a religious organization, seeks to maintain its tax-exempt status.
● The IRS (Defendant) argues the Church engages in substantial commercial activities, disqualifying it from tax exemption.
● The Church claims its activities (e.g., bookstore, bakery) are primarily religious in nature, furthering its spiritual mission.
"""

# %%
# def find_citations(text):
#     citations = []
#     keywords = ["religious", "tax-exempt", "IRS", "commercial activity"]

#     doc = nlp(text)

#     for ent in doc.ents:
#         if ent.label in ["CODE", "CASE"]:
#             citations.append(ent.text)

#     code_pattern = r"IRC § \d+\(\w+\)\(\w+\)"
#     case_pattern = r"[A-Z][a-z]+ v\. [A-Z][a-z]+ \(\d+ [A-Za-z\.]+ \d+\)"

#     for sentence in text.split("."):
#         if any(keyword in sentence.lower() for keyword in keywords):
#             if re.search(code_pattern, sentence) or re.search(case_pattern, sentence):
#                 citations.append(sentence.strip())

#     # Entity Linking
#     validated_citations = []
#     for citation in citations:
#         if validate_citation(citation):
#             validated_citations.append(citation)
    
#     return validated_citations

# %%
# def validate_citation(citation):
#     # Validate citation
#     return True

# %%
def find_citations(text):
    citations = []
    keywords = ["religious", "tax-exempt", "IRS", "commercial activity"]
    for sentence in text.split("."):
        if any(keyword in sentence.lower() for keyword in keywords):
            citations.append(sentence.strip())  # Removed leading/trailing whitespaces
    return citations

# %%
def ner_extraction(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    entities = [ent.text for ent in doc.ents if ent.label_ in ["ORG", "LAW", "DATE", "CODE", "CASE"]]  # Filter entities of interest
    return entities

# %%
def regex_extraction(text):
    regex_pattern = r'\b[A-Z][a-z]+\sv\.\s[A-Z][a-z]+(?:\s\([A-Z][a-z]+\s[A-Z][a-z]+\))?\s\(\d{1,4}\)'
    citations = re.findall(regex_pattern, text)
    return citations

# %%
def calculate_metrics(true_positives, false_positives, false_negatives):
    precision = true_positives / (true_positives + false_positives)
    recall = true_positives / (true_positives + false_negatives)
    f1_score = 2 * (precision * recall) / (precision + recall)
    return precision, recall, f1_score

# %%
def conduct_human_evaluation(predictions, ground_truth):
    # Placeholder for human evaluation implementation
    pass
